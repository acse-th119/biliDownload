# %%
import requests

import subprocess
import sys

import re
import os
import json
import time

class BiliDownloader:
    def __init__(self):
        self.start_page = 0
        self.session = requests.session()
        self.title = ''
        self.url = ''
        self.quality = 'h'



    def req_web(self, url):

        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36',
            'Content-Range': 'bytes 0-xxxxxx',
            'Referer': url
        }
        req = self.session.get(url, headers=headers)
        req.encoding = 'utf-8'
        return req.text

    def run(self, url_bili):
        req = self.req_web(url_bili)

        page_pat = re.compile('"page":(\d*?),"from".*?"part":"(.*?)",', re.S)
        name_pat = re.compile('name="keywords" content="(.*?),')
        pages = page_pat.findall(req)[self.start_page:]
        
        # remove the character which cannot exit in the name.
        filenameRemover = "[\/\\\:\*\?\"\<\>\|《》？“”’‘「」【】|、，。！@#￥%……&（）——+$ ]"
        title = re.sub(filenameRemover, '_', name_pat.findall(req)[0])
        self.title=title

        if "视频选集" in req:
            choice = input("We have multiple videos, input \n1 for all and \n0 for the first episode.\nDefault 0\n")
            if choice == '1':
                print("Video List：")
                print(*['{}_{}'.format(i[1], title) for i in pages], sep='\n')
                
                for each_page in pages:
                    each_title = re.sub(filenameRemover, '', each_page[1])
                    page_title = '{}_{}_{}'.format(each_page[0],each_title, title)
                    page_url = '{}?p={}'.format(url_bili,each_page[0])
                    self.download(page_url, page_title)

            else:
                self.download(url_bili, title)
        else:
            self.download(url_bili, title)
            
        input("\nFilm has been saved, please press Enter to quit.")

    def download(self, down_url, film_title):
        req_text = self.req_web(down_url)
        json_pat = 'window.__playinfo__=(.*?)</script><script>window.__INITIAL_STATE'
        page_info = re.compile(json_pat).findall(req_text)[0]
        page_json = json.loads(page_info)
        video_process = page_json["data"]["dash"]["video"]
        audio_url = page_json["data"]["dash"]["audio"][0]["baseUrl"]

        video = {str(i["id"]): i["baseUrl"] for i in video_process}
            
        # Modify quality
        if self.quality == 'h':
            highest_quality = sorted(video.keys(),key=lambda x:int(x))[-1]
            print('\n[Msg] We have {} quality for {}.'.format(highest_quality,film_title))
            video_url = video[highest_quality]
        else:
            if self.quality in video:
                video_url = video[self.quality]
            else:
                print("80 == 1080P\n64 == 720p\n32 == 480P\n16 == 360P\n Options：")
                for i in video:
                    print(i)
                quality = input("Your choice：")
                if quality in ["80", "64", "32", "16"]:
                    self.quality = quality
                    try:
                        video_url = video[quality]
                    except:
                        highest_quality = sorted(video.keys(),key=lambda x:int(x))[-1]
                        print('[Error]No this quality! But we have {} one.'.format(highest_quality))
                        video_url = video[highest_quality]
                else:
                    print("wrong")
                    time.sleep(5)
                    sys.exit(1)

        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36',
            'Content-Range': 'bytes 0-xxxxxx',
            'Referer': down_url
        }
        req_stream = self.session.get(video_url, stream=True, headers=headers)
        
        bv_code = down_url.split('/')[-1].split('?')[0]
        store_path = os.path.join(os.getcwd(),bv_code+'_'+self.title)

        if not os.path.exists(store_path):
            os.mkdir(store_path)

        
        video_path = os.path.join(store_path,"temp_{}.mp4".format(film_title))
        audio_path = os.path.join(store_path,"temp_{}.acc".format(film_title))
        final_path = os.path.join(store_path,"{}.mp4".format(film_title))
        
        file = open(video_path, "wb")
        length = float(req_stream.headers['content-length'])

        count = 0
        count_tmp = 0
        time1 = time.time()
        for chunk in req_stream.iter_content(chunk_size=512):
            if chunk:
                file.write(chunk)
                count += len(chunk)
                if time.time() - time1 > 1:
                    p = count / length * 100
                    speed = (count - count_tmp) / 1024 / 1
                    count_tmp = count
                    if 0 <= speed < (1024):
                        print("\r" + film_title + '   Process: ' + '{:.2f}'.format(p) + '%' + '    Speed: ' + '{:.2f}'.format(
                            speed) + 'KB/S', end="")
                    else:
                        print("\r" + film_title + '   Process: ' + '{:.2f}'.format(p) + '%' + '    Speed: ' + '{:.2f}'.format(
                            speed / 1024) + 'MB/S', end="")
                    time1 = time.time()
        file.close()

        r = self.session.get(audio_url, headers=headers)
        file = open(audio_path, "wb")
        file.write(r.content)
        file.close()
        
        
        # mac/linux version:
        # you should have ffmpeg in your PC:
        # brew install ffmpeg
        
        cmd = "ffmpeg -i {} -i {} -vcodec copy -acodec copy {}".format(video_path, audio_path, final_path)
        # print('\nAlign Code:\n',cmd)
        subprocess.call(cmd, shell=True, stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        time.sleep(5)
        
        os.remove(video_path)
        os.remove(audio_path)

#         # windows version:
#         mixer_path = os.path.join(os.getcwd(),'ffmpeg.exe')
#         if os.path.exists(mixer_path):            

#             # align the video and audio
#             cmd = "{} -i {} -i {} -vcodec copy -acodec copy {}".format(mixer_path,video_path,audio_path, final_path)
#             # print('\nAlign Code:\n',cmd)
#             subprocess.call(cmd, shell=True, stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

#             os.remove(video_path)
#             os.remove(audio_path)
#         else:
#             print("No ffmpeg for mixing, Origin Video and Audio saved.")
        
#         time.sleep(5)
        

bili = BiliDownloader()
bili.run('https://www.bilibili.com/video/BV1r4411A7Qk')
# linux运维 https://www.bilibili.com/video/BV1r4411A7Qk

# 小程序测试 https://www.bilibili.com/video/BV1PT4y1G7cy
# vue小程序 https://www.bilibili.com/video/BV1Sc41187nZ
# 28节课小程序 https://www.bilibili.com/video/BV1Ct411p7bj
# 小程序五天 https://www.bilibili.com/video/BV1c4411P7US
# 小程序开发 https://www.bilibili.com/video/BV1nE41117BQ
# 党妹视频 https://www.bilibili.com/video/BV16a4y1e7r8
# 汇丰银行吸血史 https://www.bilibili.com/video/BV1BD4y1D7Cj
# Out:
# We have multiple videos, input
# 1 for all and
# 0 for the first episode.
# Default 0
#  1
# Video List：
# 01_Linux入门系列视频-课程介绍_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 02_Linux入门系列视频-任务背景介绍+任务目标_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 03_Linux入门系列视频-计算机资源介绍_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 04_Linux入门系列视频-常见操作系统介绍_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 05_Linux入门系列视频-Linux特性介绍_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 06_Linux入门系列视频-Linux发行版本介绍_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 07_Linux入门系列视频-了解开源文化（GNU和GPL）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 08_Linux入门系列视频-祖师爷讲Linux和GNU的结合_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 09_Linux入门系列视频-Linux介绍阶段总结_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 10_Linux入门系列视频-学习环境和系统安装要求说明_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 11_Linux入门系列视频-安装RHEL8思路和步骤分析_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 12_Linux入门系列视频-创建虚拟机_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 13_Linux入门系列视频-RHEL8系统安装_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 14_Linux入门系列视频-RHEL8系统安装后续配置及系统登录_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 15_Linux入门系列视频-RHEL8系统安装总结_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 16_Linux入门系列视频-理解虚拟机快照和克隆用途_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 17_Linux入门系列视频-虚拟机拍摄快照和克隆_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 18_Linux入门系列视频-关机和重启命令_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 19_Linux入门系列视频-今日总结_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 20_Linux入门系列视频-今日目标打卡_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 01_Linux入门系列视频-RHEL8基本使用（任务背景和目标）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 02_Linux入门系列视频-RHEL8基本使用（桌面环境介绍）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 03_Linux入门系列视频-RHEL8基本使用（终端基本设置和使用）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 04_Linux入门系列视频-RHEL8基本使用（Linux下目录树结构）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 05_Linux入门系列视频-RHEL8基本使用（Linux下路径表示方法）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 06_Linux入门系列视频-RHEL8基本使用（了解bash的语法格式）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 07_Linux入门系列视频-RHEL8基本使用（了解Linux下文件类型及如何判断）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 08_Linux入门系列视频-RHEL8基本使用（ls命令讲解）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 09_Linux入门系列视频-RHEL8基本使用（mkdir命令讲解）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 10_Linux入门系列视频-RHEL8基本使用（touch命令讲解）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 11_Linux入门系列视频-RHEL8基本使用（查看文件内容相关命令讲解）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 12_Linux入门系列视频-RHEL8基本使用（cp命令讲解）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 13_Linux入门系列视频-RHEL8基本使用（mv命令讲解）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 14_Linux入门系列视频-RHEL8基本使用（rm命令讲解+总结）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 15_Linux入门系列视频-RHEL8基本使用（任务总结）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 16_Linux入门系列视频-RHEL8基本使用（Linux求帮助help命令使用）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 17_Linux入门系列视频-RHEL8基本使用（Linux求帮助man手册讲解）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 18_Linux入门系列视频-RHEL8基本使用(bash标准输入输出名词解释+符号说明)_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 19_Linux入门系列视频-RHEL8基本使用（重定向相关符号举例说明）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 20_Linux入门系列视频-RHEL8基本使用（echo命令讲解）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 21_Linux入门系列视频-RHEL8基本使用（今日内容总结）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 22_Linux入门系列视频-RHEL8基本使用（今日目标打卡）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 01_Linux入门系列视频-任务背景和任务目标_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 02_Linux入门系列视频-Linux下文件查找命令1（查找命令which和whereis）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 03_Linux入门系列视频-Linux文件查找命令find语法结构1_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 04_Linux入门系列视频-Linux文件查找命令find（根据文件名查找）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 05_Linux入门系列视频-Linux下文件查找命令find（根据文件类型查找）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 06_Linux入门系列视频-Linux下文件查找命令find（根据文件大小+属性）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 07_Linux入门系列视频-Linux下文件查找命令find（根据文件时间查找）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 08_Linux入门系列视频-Linux下文件查找命令find语法结构2+总结（找出文件执行某个命令）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 09_Linux入门系列视频-Linux下常见压缩工具介绍_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 10_Linux入门系列视频-Linux下压缩工具zip使用_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 11_Linux入门系列视频-Linux下压缩工具使用(gzip+bzip2+xz)_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 12_Linux入门系列视频-Linux下打包压缩工具tar使用1_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 13_Linux入门系列视频-Linux下打包压缩工具tar使用2_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 14_Linux入门系列视频-扩展补充date命令使用1_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 15_Linux入门系列视频-扩展补充hwclock命令_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 16_Linux入门系列视频-扩展补充timedatectl命令_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 17_Linux入门系列视频-扩展补充date应用场景_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 18_Linux入门系列视频-今日总结_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 19_Linux入门系列视频-今日目标打卡_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 01_Linux入门系列视频-任务背景说明+任务分析_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 02_Linux入门系列视频-用户概念及作用_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 03_Linux入门系列视频-用户分类_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 04_Linux入门系列视频-创建用户1（默认创建）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 05_Linux入门系列视频-创建用户2（根据需求创建）_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 06_Linux入门系列视频-用户设置密码_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
# 07_Linux入门系列视频-用户基本信息保存文件_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统
#
_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
# 29_09_Linux入门系列视频-RHEL8基本使用mkdir命令讲解_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统   Process: 74.59%    Speed: 8.00MB/S
# [Msg] We have 80 quality for 30_10_Linux入门系列视频-RHEL8基本使用touch命令讲解_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 31_11_Linux入门系列视频-RHEL8基本使用查看文件内容相关命令讲解_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
# 31_11_Linux入门系列视频-RHEL8基本使用查看文件内容相关命令讲解_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统   Process: 65.84%    Speed: 9.83MB/S
# [Msg] We have 80 quality for 32_12_Linux入门系列视频-RHEL8基本使用cp命令讲解_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 33_13_Linux入门系列视频-RHEL8基本使用mv命令讲解_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 34_14_Linux入门系列视频-RHEL8基本使用rm命令讲解总结_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 35_15_Linux入门系列视频-RHEL8基本使用任务总结_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 36_16_Linux入门系列视频-RHEL8基本使用Linux求帮助help命令使用_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 37_17_Linux入门系列视频-RHEL8基本使用Linux求帮助man手册讲解_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 38_18_Linux入门系列视频-RHEL8基本使用(bash标准输入输出名词解释符号说明)_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 39_19_Linux入门系列视频-RHEL8基本使用重定向相关符号举例说明_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 40_20_Linux入门系列视频-RHEL8基本使用echo命令讲解_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 41_21_Linux入门系列视频-RHEL8基本使用今日内容总结_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 42_22_Linux入门系列视频-RHEL8基本使用今日目标打卡_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 43_01_Linux入门系列视频-任务背景和任务目标_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 44_02_Linux入门系列视频-Linux下文件查找命令1查找命令which和whereis_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 45_03_Linux入门系列视频-Linux文件查找命令find语法结构1_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 46_04_Linux入门系列视频-Linux文件查找命令find根据文件名查找_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 47_05_Linux入门系列视频-Linux下文件查找命令find根据文件类型查找_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 48_06_Linux入门系列视频-Linux下文件查找命令find根据文件大小属性_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 49_07_Linux入门系列视频-Linux下文件查找命令find根据文件时间查找_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 50_08_Linux入门系列视频-Linux下文件查找命令find语法结构2总结找出文件执行某个命令_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 51_09_Linux入门系列视频-Linux下常见压缩工具介绍_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
# 51_09_Linux入门系列视频-Linux下常见压缩工具介绍_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统   Process: 87.02%    Speed: 6.74MB/S
# [Msg] We have 80 quality for 52_10_Linux入门系列视频-Linux下压缩工具zip使用_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 53_11_Linux入门系列视频-Linux下压缩工具使用(gzipbzip2xz)_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 54_12_Linux入门系列视频-Linux下打包压缩工具tar使用1_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 55_13_Linux入门系列视频-Linux下打包压缩工具tar使用2_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 56_14_Linux入门系列视频-扩展补充date命令使用1_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 57_15_Linux入门系列视频-扩展补充hwclock命令_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 58_16_Linux入门系列视频-扩展补充timedatectl命令_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 59_17_Linux入门系列视频-扩展补充date应用场景_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 60_18_Linux入门系列视频-今日总结_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
# 60_18_Linux入门系列视频-今日总结_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统   Process: 52.93%    Speed: 9.99MB/S
# [Msg] We have 80 quality for 61_19_Linux入门系列视频-今日目标打卡_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 62_01_Linux入门系列视频-任务背景说明任务分析_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 63_02_Linux入门系列视频-用户概念及作用_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
# 63_02_Linux入门系列视频-用户概念及作用_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统   Process: 97.39%    Speed: 5.00MB/S
# [Msg] We have 80 quality for 64_03_Linux入门系列视频-用户分类_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 65_04_Linux入门系列视频-创建用户1默认创建_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
# 65_04_Linux入门系列视频-创建用户1默认创建_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统   Process: 72.53%    Speed: 9.75MB/S
# [Msg] We have 80 quality for 66_05_Linux入门系列视频-创建用户2根据需求创建_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
# 66_05_Linux入门系列视频-创建用户2根据需求创建_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统   Process:
黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
# 182_12_Linux入门系列视频-阿里云平台部署商城系统购买ECS云主机_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统   Process: 93.51%    Speed: 4.88MB/S
# [Msg] We have 80 quality for 183_13_Linux入门系列视频-阿里云平台部署商城系统LAMP环境搭建_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
# 183_13_Linux入门系列视频-阿里云平台部署商城系统LAMP环境搭建_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统   Process: 87.86%    Speed: 6.77MB/S
# [Msg] We have 80 quality for 184_14_Linux入门系列视频-阿里云部署商城系统项目上线测试_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
# 184_14_Linux入门系列视频-阿里云部署商城系统项目上线测试_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统   Process: 53.00%    Speed: 4.98MB/S
# [Msg] We have 80 quality for 185_15_Linux入门系列视频-宝塔面板介绍及安装了解_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 186_16_Linux入门系列视频-宝塔面板部署LAMP环境_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 187_17_Linux入门系列视频-宝塔面板部署博客系统测试网页无法访问_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 188_18_Linux入门系列视频-宝塔面板部署博客系统问题解决测试验证_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
#
# [Msg] We have 80 quality for 189_19_Linux入门系列视频-今日总结_黑马程序员2019年linux云计算运维入门教程_最新的RHEL8.0操作系统.
# Film has been saved, please press Enter to quit.

# %%
a='http://upos-sz-mirrorhw.bilivideo.com/upgcxcode/87/69/201056987/201056987-1-30112.m4s?e=ig8euxZM2rNcNbdlhoNvNC8BqJIzNbfqXBvEqxTEto8BTrNvN0GvT90W5JZMkX_YN0MvXg8gNEV4NC8xNEV4N03eN0B5tZlqNxTEto8BTrNvNeZVuJ10Kj_g2UB02J0mN0B5tZlqNCNEto8BTrNvNC7MTX502C8f2jmMQJ6mqF2fka1mqx6gqj0eN0B599M=&uipk=5&nbs=1&deadline=1592041238&gen=playurl&os=hwbv&oi=1961710618&trid=bed4f520334a497ba1e630e61146fad8u&platform=pc&upsig=59079a6030bb42a8e8ec7373f2795a92&uparams=e,uipk,nbs,deadline,gen,os,oi,trid,platform&mid=48163183&orderid=0,2&logo=80000000'
headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36',
            'Content-Range': 'bytes 0-xxxxxx',
            'Referer': 'https://www.bilibili.com/video/BV1Wa4y1v7qB'
        }
r = requests.session()
req_stream = r.get(a, stream=True, headers=headers)

file = open('test.mp4', "wb")
file.write(req_stream.content)
file.close()

# %%
# !ffmpeg -i test.mp4 -i test.aac -vcodec copy -acodec copy {}
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple clang version 11.0.0 (clang-1100.0.33.17)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.2.2_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-libsoxr --enable-videotoolbox --disable-libjack --disable-indev=jack
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'test.aac':
#   Metadata:
#     major_brand     : iso5
#     minor_version   : 1
#     compatible_brands: avc1iso5dsmsmsixdash
#     encoder         : Lavf57.71.100
#     description     : Packed by Bilibili XCoder v2.0.2
#   Duration: 00:03:08.35, start: 0.000000, bitrate: 319 kb/s
#     Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 8 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to 'test.mp3':
#   Metadata:
#     major_brand     : iso5
#     minor_version   : 1
#     compatible_brands: avc1iso5dsmsmsixdash
#     description     : Packed by Bilibili XCoder v2.0.2
#     TSSE            : Lavf58.29.100
#     Stream #0:0(und): Audio: mp3 (libmp3lame), 48000 Hz, stereo, fltp (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 libmp3lame
# size=    2944kB time=00:03:08.35 bitrate= 128.0kbits/s speed=36.4x
# video:0kB audio:2943kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013205%
